# %% [markdown]
# # Course 1

# %% [markdown]
# # Final Algorithm

# %%
import pandas as pd

# %%
reviews = pd.read_csv('imdb-reviews-pt-br.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-4fe6389b78e4> in <module>
# ----> 1 reviews = pd.read_csv('imdb-reviews-pt-br.csv')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'imdb-reviews-pt-br.csv' does not exist: b'imdb-reviews-pt-br.csv'

# %%
map_sentiment = {'neg': 0,
                'pos': 1}

# %%
reviews['class'] = reviews['sentiment'].map(map_sentiment)

# %%
reviews.head()

# %%
def generate_bag_of_words(df, text_column, max_features):
    from sklearn.feature_extraction.text import CountVectorizer
    count_vectorizer = CountVectorizer(lowercase=True, max_features=max_features)
    bag_of_words = count_vectorizer.fit_transform(df[text_column])
    return bag_of_words

# %%
bag_of_words = generate_bag_of_words(
    df=reviews, 
    text_column='text_pt', 
    max_features=1000)

# %%
def generate_splited_texts(bag_of_words,df, class_column, test_size, random_state):
    from sklearn.model_selection import train_test_split
    reviews_train, reviews_test, class_train, class_test = train_test_split(
        bag_of_words, 
        df[class_column],
        test_size=test_size,
        random_state=random_state
        )
    return reviews_train, reviews_test, class_train, class_test

# %%
reviews_train, reviews_test, class_train, class_test = generate_splited_texts(
    bag_of_words,
    df=reviews, 
    class_column='class', 
    test_size=0.2, 
    random_state=200)

# %%
def classify_text(train_dataset, class_dataset, max_iter):    
    from sklearn.linear_model import LogisticRegression
    logistic_regression = LogisticRegression(solver='lbfgs', max_iter=max_iter)
    logistic_regression.fit(reviews_train, class_train)
    accuracy  = logistic_regression.score(reviews_test, class_test)
    print(f'ACURÁCIA: {accuracy}')

# %%
classify_text(
    train_dataset=reviews_train, 
    class_dataset=class_train, 
    max_iter=1000)
# Out:
# ACURÁCIA: 0.8502830570157703

# %%
df = reviews
text_column = 'text_pt'
class_column = 'class'
test_size=0.2
random_state=100
max_features = 1000
max_iter = 200
train_dataset=reviews_train 
class_dataset=class_train

# %%
def pipeline_classify_text(
    df, text_column, class_column, train_dataset, class_dataset, 
    test_size, random_state, max_features, max_iter):
    
    bag_of_words = generate_bag_of_words(df, text_column, max_features)
    
    reviews_train, reviews_test, class_train, class_test = generate_splited_texts(
        bag_of_words,
        df, 
        class_column, 
        test_size, 
        random_state)
    
    classify_text(train_dataset, class_dataset, max_iter)

# %%
pipeline_classify_text(
    df, 
    text_column, 
    class_column, 
    train_dataset, 
    class_dataset, 
    test_size, 
    random_state, 
    max_features, 
    max_iter)
# Out:
# ACURÁCIA: 0.8503841488071169
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
def generate_word_cloud(df):
    # %matplotlib inline
    from wordcloud import WordCloud
    all_words = ' '.join([ text for text in df ])
    
    word_cloud = WordCloud(
        width=800,
        height=500,
        max_font_size=110,
        collocations=False)
    
    word_cloud = word_cloud.generate(text=all_words)
    
    import matplotlib.pyplot as plt
    
    plt.figure(figsize=(10,7))

    plt.imshow(
        word_cloud, 
        interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
generate_word_cloud(
    reviews[reviews['sentiment'] == 'pos']['text_pt'])

# %% [markdown]
# # Exploration

# %%
import pandas as pd

# %%
reviews = pd.read_csv('imdb-reviews-pt-br.csv')

# %%
reviews.head()
# Out:
#    id                                            text_en  \
# 0   1  Once again Mr. Costner has dragged out a movie...
# 1   2  This is an example of why the majority of acti...
# 2   3  First of all I hate those moronic rappers, who...
# 3   4  Not even the Beatles could write songs everyon...
# 4   5  Brass pictures movies is not a fitting word fo...
#
#                                              text_pt sentiment
# 0  Mais uma vez, o Sr. Costner arrumou um filme p...       neg
# 1  Este é um exemplo do motivo pelo qual a maiori...       neg
# 2  Primeiro de tudo eu odeio esses raps imbecis, ...       neg
# 3  Nem mesmo os Beatles puderam escrever músicas ...       neg
# 4  Filmes de fotos de latão não é uma palavra apr...       neg

# %%
map_sentiment = {'neg': 0,
                'pos': 1}

# %%
reviews['class'] = reviews['sentiment'].map(map_sentiment)

# %%
reviews.head()
# Out:
#    id                                            text_en  \
# 0   1  Once again Mr. Costner has dragged out a movie...
# 1   2  This is an example of why the majority of acti...
# 2   3  First of all I hate those moronic rappers, who...
# 3   4  Not even the Beatles could write songs everyon...
# 4   5  Brass pictures movies is not a fitting word fo...
#
#                                              text_pt sentiment  class
# 0  Mais uma vez, o Sr. Costner arrumou um filme p...       neg      0
# 1  Este é um exemplo do motivo pelo qual a maiori...       neg      0
# 2  Primeiro de tudo eu odeio esses raps imbecis, ...       neg      0
# 3  Nem mesmo os Beatles puderam escrever músicas ...       neg      0
# 4  Filmes de fotos de latão não é uma palavra apr...       neg      0

# %% [markdown]
# # Data Exploration

# %%
reviews['class'].value_counts()
# Out:
# 0    24765
# 1    24694
# Name: class, dtype: int64

# %% [markdown]
# # Bag of Words
# Creates a Sparse Matrix that contains the frequency that the words occurs in vocabulary

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# The argument `max_feature` delimites the max number of words that will form the Bag of Words matrix. It will choose automatically the most relevant words

# %%
count_vectorizer = CountVectorizer(lowercase=True, max_features=10000)

# %%
bag_of_words = count_vectorizer.fit_transform(reviews['text_pt'])

# %%
bag_of_words
# Out:
# <49459x10000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5880050 stored elements in Compressed Sparse Row format>

# %%
count_vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '10',
#  '100',
#  '1000',
#  '101',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1920',
#  '1930',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1936',
#  '1938',
#  '1939',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1951',
#  '1953',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1963',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '250',
#  '26',
#  '27',
#  '28',
#  '2ª',
#  '30',
#  '300',
#  '3000',
#  '35',
#  '37',
#  '3d',
#  '40',
#  '45',
#  '50',
#  '500',
#  '60',
#  '70',
#  '73',
#  '75',
#  '80',
#  '85',
#  '90',
#  '95',
#  '98',
#  '99',
#  'aaron',
#  'abaixo',
#  'abandonada',
#  'abandonado',
#  'abandonar',
#  'abandonou',
#  'abatido',
#  'abbott',
#  'abc',
#  'aberração',
#  'aberta',
#  'abertamente',
#  'abertas',
#  'aberto',
#  'abertos',
#  'abertura',
#  'abismal',
#  'abismo',
#  'abominação',
#  'aborda',
#  'abordado',
#  'abordagem',
#  'abordar',
#  'aborrecido',
#  'aborrecimento',
#  'aborto',
#  'about',
#  'abraham',
#  'abraçar',
#  'abre',
#  'abrigo',
#  'abril',
#  'abrindo',
#  'abrir',
#  'abriu',
#  'abruptamente',
#  'abrupto',
#  'absoluta',
#  'absolutamente',
#  'absoluto',
#  'absorvente',
#  'absurda',
#  'absurdamente',
#  'absurdas',
#  'absurdo',
#  'absurdos',
#  'abundantes',
#  'abundância',
#  'abusivo',
#  'abuso',
#  'acaba',
#  'acabado',
#  'acabam',
#  'acabamos',
#  'acabar',
#  'acabaram',
#  'acabaria',
#  'acabará',
#  'acabe',
#  'acabei',
#  'acabou',
#  'academia',
#  'acampamento',
#  'acaso',
#  'aceita',
#  'aceitar',
#  'aceitação',
#  'aceite',
#  'aceito',
#  'aceitável',
#  'acelerado',
#  'aceno',
#  'acertar',
#  'acesso',
#  'acessível',
#  'acha',
#  'acham',
#  'achamos',
#  'achando',
#  'achar',
#  'acharam',
#  'achasse',
#  'achava',
#  'achavam',
#  'ache',
#  'achei',
#  'acho',
#  'achou',
#  'acidental',
#  'acidentalmente',
#  'acidente',
#  'acidentes',
#  'acima',
#  'aclamado',
#  'acompanha',
#  'acompanhado',
#  'acompanhamento',
#  'acompanhar',
#  'aconselho',
#  'acontece',
#  'acontecem',
#  'acontecendo',
#  'acontecer',
#  'aconteceram',
#  'aconteceria',
#  'acontecerá',
#  'acontecesse',
#  'aconteceu',
#  'acontecido',
#  'acontecimentos',
#  'aconteça',
#  'acorda',
#  'acordado',
#  'acordar',
#  'acordo',
#  'acostumado',
#  'acostumados',
#  'acredita',
#  'acreditado',
#  'acreditam',
#  'acreditando',
#  'acreditar',
#  'acreditava',
#  'acredite',
#  'acreditei',
#  'acredito',
#  'acreditável',
#  'acrescenta',
#  'acrescentam',
#  'acrescentar',
#  'acrescente',
#  'acrescentou',
#  'acrobacias',
#  'action',
#  'acusado',
#  'acusação',
#  'acusações',
#  'acúmulo',
#  'ad',
#  'adam',
#  'adams',
#  'adaptado',
#  'adaptar',
#  'adaptação',
#  'adaptações',
#  'adequada',
#  'adequadamente',
#  'adequado',
#  'adequados',
#  'adereços',
#  'adeus',
#  'adiante',
#  'adiciona',
#  'adicionado',
#  'adicionados',
#  'adicionais',
#  'adicional',
#  'adicionam',
#  'adicionando',
#  'adicionar',
#  'adicione',
#  'adicionou',
#  'adivinha',
#  'adivinhando',
#  'adivinhar',
#  'adivinhe',
#  'adivinhou',
#  'adição',
#  'administrar',
#  'administração',
#  'admira',
#  'admirador',
#  'admirar',
#  'admiração',
#  'admiro',
#  'admirável',
#  'admissão',
#  'admite',
#  'admitir',
#  'admito',
#  'adolescente',
#  'adolescentes',
#  'adolescência',
#  'adora',
#  'adoram',
#  'adorar',
#  'adoraram',
#  'adoraria',
#  'adorava',
#  'adoração',
#  'adorei',
#  'adormeci',
#  'adoro',
#  'adoráveis',
#  'adorável',
#  'adrian',
#  'adulta',
#  'adultas',
#  'adulto',
#  'adultos',
#  'advogado',
#  'advogados',
#  'aeroporto',
#  'afasta',
#  'afastar',
#  'afeganistão',
#  'afeição',
#  'afeta',
#  'afetado',
#  'afeto',
#  'afetou',
#  'affleck',
#  'afiada',
#  'afiado',
#  'aficionados',
#  'afinal',
#  'afirma',
#  'afirmam',
#  'afirmando',
#  'afirmar',
#  'afirmação',
#  'afirmou',
#  'africana',
#  'africano',
#  'africanos',
#  'afro',
#  'after',
#  'afunda',
#  'afundar',
#  'agarra',
#  'agarrar',
#  'age',
#  'agem',
#  'agenda',
#  'agente',
#  'agentes',
#  'agido',
#  'agindo',
#  'agir',
#  'agiram',
#  'agitado',
#  'agitação',
#  'agiu',
#  'agonia',
#  'agora',
#  'agosto',
#  'agradar',
#  'agradavelmente',
#  'agradecer',
#  'agradáveis',
#  'agradável',
#  'agressivo',
#  'agressão',
#  'agridoce',
#  'aguentar',
#  'agência',
#  'ah',
#  'ai',
#  'aids',
#  'ainda',
#  'air',
#  'ajuda',
#  'ajudado',
#  'ajudam',
#  'ajudando',
#  'ajudante',
#  'ajudar',
#  'ajudaram',
#  'ajude',
#  'ajudou',
#  'ajudá',
#  'ajuste',
#  'aka',
#  'akshay',
#  'al',
#  'ala',
#  'alan',
#  'albert',
#  'alcance',
#  'alcança',
#  'alcançado',
#  'alcançar',
#  'alcançou',
#  'alcoólatra',
#  'aldeia',
#  'aldeões',
#  'aleatoriamente',
#  'aleatória',
#  'aleatórias',
#  'aleatório',
#  'aleatórios',
#  'alec',
#  'alegando',
#  'alegre',
#  'alegremente',
#  'alegres',
#  'alegria',
#  'aleijado',
#  'alemanha',
#  'alemã',
#  'alemães',
#  'alemão',
#  'alerta',
#  'alex',
#  'alexander',
#  'alexandra',
#  'alfred',
#  'algo',
#  'algum',
#  'alguma',
#  'algumas',
#  'alguns',
#  'alguém',
#  'ali',
#  'aliados',
#  'alice',
#  'alicia',
#  'alien',
#  'aliens',
#  'alienígena',
#  'alienígenas',
#  'alimenta',
#  'alimentar',
#  'alison',
#  'alive',
#  'aliviar',
#  'aliás',
#  'all',
#  'allen',
#  'allens',
#  'alma',
#  'almas',
#  'almoço',
#  'alone',
#  'alta',
#  'altamente',
#  'altas',
#  'alter',
#  'alterado',
#  'alternativa',
#  'alternativo',
#  'altman',
#  'alto',
#  'altos',
#  'altura',
#  'alturas',
#  'alugando',
#  'alugar',
#  'alugue',
#  'aluguei',
#  'aluguel',
#  'alugá',
#  'aluno',
#  'alunos',
#  'alvin',
#  'alvo',
#  'alvos',
#  'além',
#  'alívio',
#  'ama',
#  'amada',
#  'amado',
#  'amador',
#  'amadora',
#  'amadores',
#  'amam',
#  'amamos',
#  'amanda',
#  'amando',
#  'amanhã',
#  'amante',
#  'amantes',
#  'amar',
#  'amarelo',
#  'amarga',
#  'amargo',
#  'amarrado',
#  'amarrar',
#  'amava',
#  'amazon',
#  'ambas',
#  'amber',
#  'ambiciosa',
#  'ambicioso',
#  'ambientada',
#  'ambientado',
#  'ambiente',
#  'ambientes',
#  'ambição',
#  'ambições',
#  'ambos',
#  'ambíguo',
#  'ame',
#  'ameaça',
#  'ameaçador',
#  'ameaçando',
#  'ameaças',
#  'amei',
#  'america',
#  'american',
#  'americana',
#  'americanas',
#  'americano',
#  'americanos',
#  'amiga',
#  'amigas',
#  'amigo',
#  'amigos',
#  'amigável',
#  'amir',
#  'amitabh',
#  'amizade',
#  'amizades',
#  'amo',
#  'amor',
#  'amorosa',
#  'amoroso',
#  'amorosos',
#  'amou',
#  'ampla',
#  'amplamente',
#  'amplo',
#  'amy',
#  'amá',
#  'amáveis',
#  'amável',
#  'américa',
#  'américas',
#  'an',
#  'analisar',
#  'and',
#  'anda',
#  'andam',
#  'andamento',
#  'andando',
#  'andar',
#  'andares',
#  'anderson',
#  'andre',
#  'andrew',
#  'andrews',
#  'andy',
#  'anel',
#  'anfitrião',
#  'angel',
#  'angela',
#  'angeles',
#  'angelina',
#  'angels',
#  'angustiante',
#  'angústia',
#  'animada',
#  'animadas',
#  'animado',
#  'animadores',
#  'animados',
#  'animais',
#  'animal',
#  'animar',
#  'animação',
#  'animações',
#  'anime',
#  'aniversário',
#  'anjo',
#  'anjos',
#  'ann',
#  'anna',
#  'anne',
#  'annie',
#  'ano',
#  'anos',
#  'anseia',
#  'ansiosamente',
#  'ansioso',
#  'antagonista',
#  'antecessor',
#  'antecipação',
#  'anterior',
#  'anteriores',
#  'anteriormente',
#  'antes',
#  'anthony',
#  'anti',
#  'antiga',
#  'antigas',
#  'antigo',
#  'antigos',
#  'antiquado',
#  'antologia',
#  'anton',
#  'antonio',
#  'antonioni',
#  'antwone',
#  'anuncia',
#  'anunciado',
#  'análise',
#  'anão',
#  'anéis',
#  'anúncio',
#  'anúncios',
#  'ao',
#  'aos',
#  'apaixona',
#  'apaixonada',
#  'apaixonado',
#  'apaixonados',
#  'apaixonam',
#  'apaixonando',
#  'apaixonar',
#  'apaixonei',
#  'apaixonou',
#  'aparece',
#  'aparecem',
#  'aparecendo',
#  'aparecer',
#  'apareceram',
#  'aparecesse',
#  'apareceu',
#  'aparelho',
#  'aparelhos',
#  'aparente',
#  'aparentemente',
#  'aparentes',
#  'apareça',
#  'aparição',
#  'aparições',
#  'apartamento',
#  'apartamentos',
#  'aparência',
#  'apelar',
#  'apelidado',
#  'apelo',
#  'apenas',
#  'apertado',
#  'apertar',
#  'apesar',
#  'aplausos',
#  'aplica',
#  'apocalipse',
#  'apocalypse',
#  'apocalíptico',
#  'apoiado',
#  'apoiar',
#  'apoio',
#  'aponta',
#  'apontando',
#  'apontar',
#  'apontou',
#  'aposentado',
#  'aposta',
#  'apostar',
#  'apostas',
#  'aposto',
#  'aprecia',
#  'apreciado',
#  'apreciam',
#  'apreciar',
#  'apreciará',
#  'apreciação',
#  'aprecie',
#  'apreciei',
#  'aprecio',
#  'apreciá',
#  'aprenda',
#  'aprende',
#  'aprendem',
#  'aprendemos',
#  'aprendendo',
#  'aprender',
#  'aprendeu',
#  'aprendi',
#  'aprendido',
#  'apresenta',
#  'apresentada',
#  'apresentadas',
#  'apresentado',
#  'apresentador',
#  'apresentados',
#  'apresentam',
#  'apresentando',
#  'apresentar',
#  'apresentação',
#  'apresentações',
#  'apresentou',
#  'apressado',
#  'apropriada',
#  'apropriadamente',
#  'apropriado',
#  'aprovação',
#  'aproveita',
#  'aproveitar',
#  'aproveite',
#  'aproxima',
#  'aproximadamente',
#  'aproximando',
#  'aproximar',
#  'apuros',
#  'após',
#  'aquecimento',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aqui',
#  'aquilo',
#  'aquém',
#  'ar',
#  'aranha',
#  'arca',
#  'arco',
#  'ardente',
#  'areia',
#  'argento',
#  'argumentar',
#  'argumento',
#  'argumentos',
#  'ariel',
#  'arizona',
#  'arma',
#  'armadas',
#  'armadilha',
#  'armadilhas',
#  'armados',
#  'armadura',
#  'armas',
#  'armstrong',
#  'armário',
#  'arnold',
#  'arquette',
#  'arquiteto',
#  'arquivo',
#  'arquivos',
#  'arrancado',
#  'arrancar',
#  'arrasta',
#  'arrastado',
#  'arrastando',
#  'arrastar',
#  'arrastou',
#  'arredores',
#  'arregalados',
#  'arrepender',
#  'arrependimento',
#  'arrependo',
#  'arrepiante',
#  'arrepiantes',
#  'arrepios',
#  'arriscar',
#  'arrogante',
#  'arrogância',
#  'arruinado',
#  'arruinar',
#  'arruinou',
#  'art',
#  'arte',
#  'artes',
#  'arthur',
#  'artificial',
#  'artifício',
#  'artigo',
#  'artista',
#  'artistas',
#  'artisticamente',
#  'artística',
#  'artísticas',
#  'artístico',
#  'artísticos',
#  'as',
#  'asas',
#  'ascensão',
#  'ashley',
#  'asilo',
#  'asiática',
#  'asiático',
#  'asiáticos',
#  'aspecto',
#  'aspectos',
#  'aspirante',
#  'aspirantes',
#  'assalto',
#  'assassina',
#  'assassinada',
#  'assassinado',
#  'assassinados',
#  'assassinar',
#  'assassinato',
#  'assassinatos',
#  'assassino',
#  'assassinos',
#  'assassinou',
#  'assemelha',
#  'assento',
#  'assentos',
#  'assim',
#  'assinar',
#  'assista',
#  'assistam',
#  'assiste',
#  'assistem',
#  'assistente',
#  'assisti',
#  'assistia',
#  'assistido',
#  'assistimos',
#  'assistindo',
#  'assistir',
#  'assistiram',
#  'assistirem',
#  'assistisse',
#  'assistiu',
#  'assisto',
#  'assistível',
#  'associado',
#  'associados',
#  'associação',
#  'assombrada',
#  'assombrado',
#  'assombrosa',
#  'assume',
#  'assumem',
#  'assumindo',
#  'assumir',
#  'assumiu',
#  'assunto',
#  'assuntos',
#  'assusta',
#  'assustada',
#  'assustado',
#  'assustador',
#  'assustadora',
#  'assustadoramente',
#  'assustadoras',
#  'assustadores',
#  'assustar',
#  'assustou',
#  'astaire',
#  'asterix',
#  'astro',
#  'astronauta',
#  'astronautas',
#  'astuto',
#  'at',
#  'ataca',
#  'atacada',
#  'atacado',
#  'atacados',
#  'atacam',
#  'atacando',
#  'atacar',
#  'ataque',
#  'ataques',
#  'atemporal',
#  'atende',
#  'atender',
#  'atento',
#  'atenção',
#  'atenções',
#  'aterrorizante',
#  'atinge',
#  'atingido',
#  'atingir',
#  'atingiu',
#  'atira',
#  'atirador',
#  'atirando',
#  'atirar',
#  'atirou',
#  'atitude',
#  'atitudes',
#  'atividade',
#  'atividades',
#  'atlantis',
#  'atleta',
#  'atletas',
#  'atlântico',
#  'atmosfera',
#  'atmosférico',
#  'ato',
#  'ator',
#  'atores',
#  'atormentado',
#  'atos',
#  'atraente',
#  'atraentes',
#  'atrai',
#  'atrair',
#  'atraiu',
#  'atrasado',
#  'atravessa',
#  'atravessar',
#  'através',
#  'atração',
#  'atraída',
#  'atraído',
#  'atraídos',
#  'atrevida',
#  'atrevido',
#  'atriz',
#  'atrizes',
#  'atrocidade',
#  'atrocidades',
#  'atroz',
#  'atrás',
#  'attenborough',
#  'atua',
#  'atuado',
#  'atuais',
#  'atual',
#  'atualização',
#  'atualmente',
#  'atuando',
#  'atuar',
#  'atuação',
#  'atuações',
#  'atuou',
#  'até',
#  'audição',
#  'audiência',
#  'audiências',
#  'audrey',
#  'auge',
#  'aula',
#  'aulas',
#  'aumenta',
#  'aumentam',
#  'aumentando',
#  'aumentar',
#  'aumento',
#  'aura',
#  'ausente',
#  'ausentes',
#  'austen',
#  'austens',
#  'austin',
#  'australiana',
#  'australiano',
#  'australianos',
#  'austrália',
#  'ausência',
#  'autenticidade',
#  'auto',
#  'autobiografia',
#  'automaticamente',
#  'autor',
#  'autores',
#  'autoridade',
#  'autoridades',
#  'autêntica',
#  'autêntico',
#  'avaliado',
#  'avaliar',
#  'avaliação',
#  'avaliações',
#  'avaliei',
#  'avança',
#  'avançado',
#  'avançar',
#  'avanço',
#  'avanços',
#  'aventura',
#  'aventuras',
#  'avisado',
#  'avisar',
#  'aviso',
#  'avisá',
#  'avião',
#  'aviões',
#  'avó',
#  'avós',
#  'avô',
#  'away',
#  'azuis',
#  'azul',
#  'aço',
#  'açougueiro',
#  'ação',
#  'ações',
#  'açúcar',
#  'aérea',
#  ...]

# %%
df_esparso = pd.SparseDataFrame(bag_of_words, columns = count_vectorizer.get_feature_names())
# Out:
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   """Entry point for launching an IPython kernel.
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\sparse\frame.py:257: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   sparse_index=BlockIndex(N, blocs, blens),

# %%
df_esparso.head()
# Out:
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\sparse\frame.py:745: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=self._default_fill_value,
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\sparse\frame.py:721: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=self._default_fill_value,
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\sparse\frame.py:745: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   default_fill_value=self._default_fill_value,
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5997: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return self._constructor(data).__finalize__(self)
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:392: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return cls(data, **kwargs)
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
#     00  000   10  100  11  12  13  14  15  16  ...  ônibus  última  últimas  \
# 0  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN  ...     NaN     NaN      NaN
# 1  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN  ...     NaN     NaN      NaN
# 2  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN  ...     NaN     NaN      NaN
# 3  1.0  NaN  1.0  NaN NaN NaN NaN NaN NaN NaN  ...     NaN     NaN      NaN
# 4  NaN  NaN  NaN  NaN NaN NaN NaN NaN NaN NaN  ...     NaN     NaN      NaN
#
#    último  últimos  única  únicas  único  únicos  útil
# 0     NaN      NaN    NaN     NaN    NaN     NaN   NaN
# 1     NaN      NaN    NaN     NaN    NaN     NaN   NaN
# 2     NaN      NaN    NaN     NaN    NaN     NaN   NaN
# 3     NaN      NaN    1.0     NaN    NaN     NaN   NaN
# 4     NaN      NaN    NaN     NaN    NaN     NaN   NaN
#
# [5 rows x 5000 columns]

# %% [markdown]
# # Data split in train and test dataset

# %%
from sklearn.model_selection import train_test_split

# %%
reviews_train, reviews_test, class_train, class_test = train_test_split(
    bag_of_words, 
    reviews['class'],
    test_size=0.2,
    random_state=42
    )

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_regression = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
logistic_regression.fit(reviews_train, class_train)
accuracy  = logistic_regression.score(reviews_test, class_test)
# Out:
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
print(accuracy)
# Out:
# 0.8669632025879499

# %%
def classify_text(df, text_column, class_column, max_features, test_size, max_iter):
    from sklearn.feature_extraction.text import CountVectorizer
    count_vectorizer = CountVectorizer(lowercase=True, max_features=max_features)
    bag_of_words = count_vectorizer.fit_transform(df[text_column])
    
    from sklearn.model_selection import train_test_split
    reviews_train, reviews_test, class_train, class_test = train_test_split(
        bag_of_words, 
        df[class_column],
        test_size=test_size,
        random_state=42
        )
    
    from sklearn.linear_model import LogisticRegression
    logistic_regression = LogisticRegression(solver='lbfgs', max_iter=max_iter)
    logistic_regression.fit(reviews_train, class_train)
    accuracy  = logistic_regression.score(reviews_test, class_test)
    print(f'ACURÁCIA: {accuracy}')

# %%
classify_text(
    df = reviews,
    text_column='text_pt',
    class_column='class',
    max_features=200,
    test_size=0.2,
    max_iter=200)
# Out:
# ACURÁCIA: 0.7675899716942984

# %%
classify_text(
    df = reviews,
    text_column='text_pt',
    class_column='class',
    max_features=100,
    test_size=0.2,
    max_iter=200)
# Out:
# ACURÁCIA: 0.7122927618277396

# %%
classify_text(
    df = reviews,
    text_column='text_pt',
    class_column='class',
    max_features=1000,
    test_size=0.2,
    max_iter=200)
# Out:
# ACURÁCIA: 0.8527092600080873
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
classify_text(
    df = reviews,
    text_column='text_pt',
    class_column='class',
    max_features=5000,
    test_size=0.2,
    max_iter=200)
# Out:
# ACURÁCIA: 0.8680752122927619
# C:\Users\lucasrcs\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %% [markdown]
# # WordCloud

# %%
# %matplotlib inline

# %%
from wordcloud import WordCloud

# %%
all_words = ' '.join([ text for text in reviews['text_pt'] ])

# %%
word_cloud = WordCloud(
    width=800,
    height=500,
    max_font_size=110,
    collocations=False)

# %%
word_cloud = word_cloud.generate(text=all_words)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,7))

plt.imshow(
    word_cloud, 
    interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
reviews[reviews['sentiment'] == 'pos']
# Out:
#           id                                            text_en  \
# 12389  12391  I went and saw this movie last night after bei...
# 12390  12392  Actor turned director Bill Paxton follows up h...
# 12391  12393  As a recreational golfer with some knowledge o...
# 12392  12394  I saw this film in a sneak preview, and it is ...
# 12393  12395  Bill Paxton has taken the true story of the 19...
# ...      ...                                                ...
# 49454  49456  Seeing as the vote average was pretty low, and...
# 49455  49457  The plot had some wretched, unbelievable twist...
# 49456  49458  I am amazed at how this movieand most others h...
# 49457  49459  A Christmas Together actually came before my t...
# 49458  49460  Working-class romantic drama from director Mar...
#
#                                                  text_pt sentiment  class
# 12389  Eu fui e vi este filme ontem à noite depois de...       pos      1
# 12390  O diretor do ator, Bill Paxton, segue sua prom...       pos      1
# 12391  Como um jogador de recreio com algum conhecime...       pos      1
# 12392  Eu vi esse filme em uma prévia, e é delicioso....       pos      1
# 12393  Bill Paxton levou a verdadeira história do gol...       pos      1
# ...                                                  ...       ...    ...
# 49454  Como a média de votos era muito baixa, e o fat...       pos      1
# 49455  O enredo teve algumas reviravoltas infelizes e...       pos      1
# 49456  Estou espantado com a forma como este filme e ...       pos      1
# 49457  A Christmas Together realmente veio antes do m...       pos      1
# 49458  O drama romântico da classe trabalhadora do di...       pos      1
#
# [24694 rows x 5 columns]

# %%
reviews[reviews['sentiment'] == 'neg']['text_pt']
# Out:
# 0        Mais uma vez, o Sr. Costner arrumou um filme p...
# 1        Este é um exemplo do motivo pelo qual a maiori...
# 2        Primeiro de tudo eu odeio esses raps imbecis, ...
# 3        Nem mesmo os Beatles puderam escrever músicas ...
# 4        Filmes de fotos de latão não é uma palavra apr...
#                                ...
# 37113    No final do filme, senti que era muito técnico...
# 37114    Este é o tipo de filme que meus inimigos me as...
# 37115    Eu vi Descent na noite passada no Stockholm Fi...
# 37116    Alguns filmes que você escolhe por um quilo sã...
# 37117    Este é um dos filmes mais idiotas que já vi. E...
# Name: text_pt, Length: 24765, dtype: object

# %%
def generate_word_cloud(df):
    # %matplotlib inline
    from wordcloud import WordCloud
    all_words = ' '.join([ text for text in df ])
    
    word_cloud = WordCloud(
        width=800,
        height=500,
        max_font_size=110,
        collocations=False)
    
    word_cloud = word_cloud.generate(text=all_words)
    
    import matplotlib.pyplot as plt
    
    plt.figure(figsize=(10,7))

    plt.imshow(
        word_cloud, 
        interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
generate_word_cloud(
    reviews[reviews['sentiment'] == 'neg']['text_pt'])

# %%
generate_word_cloud(
    reviews[reviews['sentiment'] == 'pos']['text_pt'])

# %%
import nltk

# %%
all_words = ' '.join([ text.lower() for text in reviews['text_pt'] ]).split()

# %%
frequencia = nltk.FreqDist(all_words)

# %%
frequencia
# Out:
# FreqDist({'de': 422154, 'que': 327261, 'e': 311782, 'o': 289805, 'a': 241726, 'um': 225146, 'é': 208453, 'não': 142163, 'em': 140213, 'uma': 136215, ...})

# %%
df_freq = pd.DataFrame({
    'word': list(frequencia.keys()),
    'frequency': list(frequencia.values())
})

# %%
df_freq
# Out:
#               word  frequency
# 0             mais      55117
# 1              uma     136215
# 2             vez,       1929
# 3                o     289805
# 4              sr.       1836
# ...            ...        ...
# 312119  muppified,          1
# 312120   inventora          1
# 312121      "union          1
# 312122      beirar          1
# 312123    rosados.          1
#
# [312124 rows x 2 columns]

# %%
import seaborn as sns

# %%
df_sliced = df_freq.nlargest(n = 30, columns='frequency')

# %%
plt.figure(figsize=(16, 8))
ax = sns.barplot(data=df_sliced, x='word', y='frequency')
ax.set(xlabel = 'Palavras')
ax.set(ylabel = 'Frequência')
plt.show()

# %% [markdown]
# # Course 2

# %%
import pandas as pd

# %%
reviews = pd.read_csv('imdb-reviews-pt-br.csv')

# %%
reviews.head()
# Out:
#    id                                            text_en  \
# 0   1  Once again Mr. Costner has dragged out a movie...
# 1   2  This is an example of why the majority of acti...
# 2   3  First of all I hate those moronic rappers, who...
# 3   4  Not even the Beatles could write songs everyon...
# 4   5  Brass pictures movies is not a fitting word fo...
#
#                                              text_pt sentiment
# 0  Mais uma vez, o Sr. Costner arrumou um filme p...       neg
# 1  Este é um exemplo do motivo pelo qual a maiori...       neg
# 2  Primeiro de tudo eu odeio esses raps imbecis, ...       neg
# 3  Nem mesmo os Beatles puderam escrever músicas ...       neg
# 4  Filmes de fotos de latão não é uma palavra apr...       neg

# %%
from nltk import tokenize

# %%
frase = 'Olá Mundo!'
token_pontuacao = tokenize.WordPunctTokenizer()
token_frase = token_pontuacao.tokenize(frase)
token_frase
# Out:
# ['Olá', 'Mundo', '!']

# %%
from string import punctuation

# %%
punctuation_list = list(punctuation)

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('portuguese')

# %%
stop_words = stop_words + punctuation_list
stop_words
# Out:
# ['de',
#  'a',
#  'o',
#  'que',
#  'e',
#  'é',
#  'do',
#  'da',
#  'em',
#  'um',
#  'para',
#  'com',
#  'não',
#  'uma',
#  'os',
#  'no',
#  'se',
#  'na',
#  'por',
#  'mais',
#  'as',
#  'dos',
#  'como',
#  'mas',
#  'ao',
#  'ele',
#  'das',
#  'à',
#  'seu',
#  'sua',
#  'ou',
#  'quando',
#  'muito',
#  'nos',
#  'já',
#  'eu',
#  'também',
#  'só',
#  'pelo',
#  'pela',
#  'até',
#  'isso',
#  'ela',
#  'entre',
#  'depois',
#  'sem',
#  'mesmo',
#  'aos',
#  'seus',
#  'quem',
#  'nas',
#  'me',
#  'esse',
#  'eles',
#  'você',
#  'essa',
#  'num',
#  'nem',
#  'suas',
#  'meu',
#  'às',
#  'minha',
#  'numa',
#  'pelos',
#  'elas',
#  'qual',
#  'nós',
#  'lhe',
#  'deles',
#  'essas',
#  'esses',
#  'pelas',
#  'este',
#  'dele',
#  'tu',
#  'te',
#  'vocês',
#  'vos',
#  'lhes',
#  'meus',
#  'minhas',
#  'teu',
#  'tua',
#  'teus',
#  'tuas',
#  'nosso',
#  'nossa',
#  'nossos',
#  'nossas',
#  'dela',
#  'delas',
#  'esta',
#  'estes',
#  'estas',
#  'aquele',
#  'aquela',
#  'aqueles',
#  'aquelas',
#  'isto',
#  'aquilo',
#  'estou',
#  'está',
#  'estamos',
#  'estão',
#  'estive',
#  'esteve',
#  'estivemos',
#  'estiveram',
#  'estava',
#  'estávamos',
#  'estavam',
#  'estivera',
#  'estivéramos',
#  'esteja',
#  'estejamos',
#  'estejam',
#  'estivesse',
#  'estivéssemos',
#  'estivessem',
#  'estiver',
#  'estivermos',
#  'estiverem',
#  'hei',
#  'há',
#  'havemos',
#  'hão',
#  'houve',
#  'houvemos',
#  'houveram',
#  'houvera',
#  'houvéramos',
#  'haja',
#  'hajamos',
#  'hajam',
#  'houvesse',
#  'houvéssemos',
#  'houvessem',
#  'houver',
#  'houvermos',
#  'houverem',
#  'houverei',
#  'houverá',
#  'houveremos',
#  'houverão',
#  'houveria',
#  'houveríamos',
#  'houveriam',
#  'sou',
#  'somos',
#  'são',
#  'era',
#  'éramos',
#  'eram',
#  'fui',
#  'foi',
#  'fomos',
#  'foram',
#  'fora',
#  'fôramos',
#  'seja',
#  'sejamos',
#  'sejam',
#  'fosse',
#  'fôssemos',
#  'fossem',
#  'for',
#  'formos',
#  'forem',
#  'serei',
#  'será',
#  'seremos',
#  'serão',
#  'seria',
#  'seríamos',
#  'seriam',
#  'tenho',
#  'tem',
#  'temos',
#  'tém',
#  'tinha',
#  'tínhamos',
#  'tinham',
#  'tive',
#  'teve',
#  'tivemos',
#  'tiveram',
#  'tivera',
#  'tivéramos',
#  'tenha',
#  'tenhamos',
#  'tenham',
#  'tivesse',
#  'tivéssemos',
#  'tivessem',
#  'tiver',
#  'tivermos',
#  'tiverem',
#  'terei',
#  'terá',
#  'teremos',
#  'terão',
#  'teria',
#  'teríamos',
#  'teriam',
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %% [markdown]
# É necessário retirar a pontuação, pois mesmo usando o CountVectorizer para realizar a representação em Bag of Words, nós criamos a função pareto, que por sua vez não remove a pontuação automaticamente. Portanto, para que o pareto represente a frequência das palavras, o mais próximo possível da frequência da representação Bag of W\ords é importante remover as pontuações do nosso corpus.

# %%
processed_phrases = list()
for review in reviews['text_pt']:
    new_phrase = list()
    tokens = token_pontuacao.tokenize(review)
    new_phrase = [token for token in tokens if token not in stop_words]
    #for token in tokens:
    #    new_phrase = [token if token not in stop_words]
    processed_phrases.append(' '.join(new_phrase))

# %%
len(processed_phrases)
# Out:
# 49459

# %%
processed_phrases
# Out:
# ['Mais vez Sr Costner arrumou filme tempo necessário Além terríveis seqüências resgate mar quais poucas simplesmente importei nenhum personagens A maioria fantasmas armário personagem Costers realizado logo início esquecido tarde importava O personagem deveríamos importar arrogante superconfiante Ashton Kutcher O problema sai garoto pensa melhor qualquer outra pessoa redor mostra sinais armário desordenado Seu único obstáculo parece estar vencendo Costner Finalmente bem além meio caminho Costner conta sobre fantasmas Kutchers Somos informados Kutcher levado ser melhor pressentimentos presságios anteriores Nenhuma mágica aqui tudo podia fazer desligar hora',
#  'Este exemplo motivo maioria filmes ação mesmos Genérico chato nada valha pena assistir aqui Um completo desperdício talentos Ice T Cubo Gelo mal aproveitados cada comprovando capazes atuar agir bem Não incomode vá ver New Jack City Ricochet assistir New York Undercover Ice T Boyz Hood Higher Learning Friday Ice Cube ver negócio real Ice Ts horrivelmente clichê diálogo sozinho faz filme ralar dentes ainda perguntando diabos Bill Paxton fazendo neste filme E diabos sempre interpreta exatamente personagem Dos extraterrestres diante todos filmes vi Bill Paxton fizeram interpretar exatamente personagem irritante menos Aliens personagem morreu tornou pouco gratificante ... No geral lixo ação segunda classe Existem incontáveis \u200b\u200b filmes melhores ver realmente quiser ver filme assista Judgment Night praticamente cópia carbono melhor atuação roteiro melhor A única coisa fez valer pena assistir mão decente câmera cinematografia quase refrescante chega perto compensar horrível filme si bem assim 4 10',
